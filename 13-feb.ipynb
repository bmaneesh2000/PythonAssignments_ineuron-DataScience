# %%
#1

"""
Q1. Explain why we have to use the Exception class while creating a Custom Exception.

Note: Here Exception class refers to the base class for all the exceptions.
"""

#Answer

"""
To create an user defined exception we need to inheret an Exception class as our base class.
The Exception class is an inbuilt class used and all non-system-exiting exceptions are derived from this class. 
All user-defined exceptions should also be derived from this class.
"""

#Example

class BadName(Exception):
    "Bad name maneesh"
    pass

name="maneesh"

try:
    if name=="maneesh":
        raise BadName
        
except BadName:
    print("Exception occurred: Badname")
# Out:
# Exception occurred: Badname

# %%
#2

""" 
Q2. Write a python program to print Python Exception Hierarchy.
"""

#Answers

#Program writes it down in a file since op dosent fit in here

import inspect
def treeClass(cls, ind = 0):
    print ('-' * ind, cls.__name__)
    f.write( '-' * ind+str(cls.__name__)+"\n")
    for i in cls.__subclasses__():
        treeClass(i, ind + 3)
f = open("text1.txt","w")
print("Hierarchy for Built-in exceptions is : ")
inspect.getclasstree(inspect.getmro(BaseException))
treeClass(BaseException)
f.close()
# Out:
# Hierarchy for Built-in exceptions is :
#  BaseException
# --- Exception
# ------ TypeError
# --------- FloatOperation
# --------- MultipartConversionError
# ------ StopAsyncIteration
# ------ StopIteration
# ------ ImportError
# --------- ModuleNotFoundError
# --------- ZipImportError
# ------ OSError
# --------- ConnectionError
# ------------ BrokenPipeError
# ------------ ConnectionAbortedError
# ------------ ConnectionRefusedError
# ------------ ConnectionResetError
# --------------- RemoteDisconnected
# --------- BlockingIOError
# --------- ChildProcessError
# --------- FileExistsError
# --------- FileNotFoundError
# --------- IsADirectoryError
# --------- NotADirectoryError
# --------- InterruptedError
# ------------ InterruptedSystemCall
# --------- PermissionError
# --------- ProcessLookupError
# --------- TimeoutError
# --------- UnsupportedOperation
# --------- itimer_error
# --------- herror
# --------- gaierror
# --------- SSLError
# ------------ SSLCertVerificationError
# ...

# %%
#3

"""Q3. What errors are defined in the ArithmeticError class? Explain any two with an example."""

#Answers

"""
AritmationError Class is derived from the Exceptions Class as its base 
The arithmetic error occurs when an error is encountered during numeric calculations in Python. 
This includes Zerodivision Error ,Floating point error and Overflow Error.
"""
#Examples

#a

try:
    j=5/0
except ZeroDivisionError as e:
    print("Zero Division Error")

#b

try:
    import math
    print(math.exp(1000))
except OverflowError as e:
    print("Overflow error happened")
# Out:
# Zero Division Error
# Overflow error happened

# %%
#Q4

""" Q4. Why LookupError class is used? Explain with an example KeyError and IndexError."""

#Answer

"""
The LookupError exception in Python forms the base class for all exceptions that are raised when an index or a key is not found for a sequence or dictionary respectively.
You can use LookupError exception class to handle both IndexError and KeyError exception classes
"""

#Examples

#KeyError: 

try:
    d={"name": "maneesh", "age": 200}
    print(d["phone"])
except KeyError as e:
    print("No Key like that exists")

#IndexError: 

try:
    l=[1,2,3,4,5]
    print(l[20])
except IndexError as e:
    print("Index out of bounds")
# Out:
# No Key like that exists
# Index out of bounds

# %%
#5

""" Q5. Explain ImportError. What is ModuleNotFoundError? """

#Answer

""" 
Import error occurs when an imported class is not accessible or is in a circular dependency. 

The imported class is in a circular dependency.
The imported class is unavailable or was not created.
The imported class name is misspelled.
The imported class from a module is misplaced.
The imported class is unavailable in the Python library.

Where ModuleNotFoundError is raised when no module with the same module name you require to import exists it the directory.

"""

#Example

try:
 import DosentExist
except ModuleNotFoundError as e:
    print(" No module named that exists")
# Out:
#  No module named that exists

# %%
#6

""" Q6. List down some best practices for exception handling in python."""

#Answers

""" 
# Always use specific exceptions and avoid to use the exceptions superclass alone to increase efficiancy
# Always print the valid message as it will be useful for debugging
# Always try to use the logging module and log in a permenant file for verification and debugging.
# Avoid to write multiple exception handlings for several unrelated and unnecessary errors.
# Clean up all resourses after you use them ie. Close the files, disconnect databases etc
# Prepare proper documentation for your code so others can understand


"""
